# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Python modules

# %% [markdown]
# This notebook accompanies the walk-through video on Python modules and packages and also contains a few additional examples on how we can use modules.

# %% [markdown]
# ## Learning objectives
# In this train, we will learn how to:
# - Write a module and import all or specific objects from a module.
# - Import modules using an alias name and explore the use of built-in modules.
#
#
# ## Outline
# To do this, we will:
# - Define the importance of modules and packages in programming.
# - Review the syntax and conventions for importing modules.
# - Consider the use of built-in Python modules.

# %% [markdown]
# ## Introduction
# Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, **modularisation** is implemented using functions, modules, and packages.
#
# A **module** is a file consisting of Python code. A module can define functions, classes, variables, and runnable code. These modules can be imported and referenced from other Python code. A **Python package** (also referred to as a library) is a collection of hierarchically structured directories of Python code consisting of sub-packages and modules.
#
# Modules and packages are two mechanisms that facilitate modular programming.
#
# ## Why modularisation?
#
# * **Reusability**: Eliminates the need to write new code, as functionality defined in a single module can be easily reused.
#
#
# * **Simplicity**: Modules generally tend to focus on a selected area of the problem which is usually small, rather than focusing on the entire problem at hand. Integrating the use of selected modules will result in systematically dealing with each small problem in the code, making development easier and less error-prone.
#
#
# * **Maintainability**: Modules in Python are often designed to be self-supporting. In this sense, one module does not depend entirely upon other modules to work. Therefore, it is unlikely that modifying a single module of a program will affect other parts of the program. This allows a team of many programmers or data scientists to work collaboratively on a large application.

# %% [markdown]
# ## Working with modules
#
# ### Creating modules
# Creating a module is as simple as saving a Python script with functions, classes, variables and running code. The file name is the module name with the suffix `.py` appended.
#
# ### Importing modules
# We can access this module and its elements from a different Python file by using the `import` statement.
# * We can import a single module/package:
#
#     ```python
#     import <module_name>
#     ```
#
# * Import multiple modules using individual import statements:
#
#     ```python
#     import <module_1_name>
#     import <module_2_name>
#     import <module_3_name>
#     ...```
#
#
#
# The same rules apply when dealing with packages. We can import specific modules within a package by using dot notation. For this to work, we have to structure packages and modules in a way that reflects the hierarchy in the package directory.
#
#    ```python
#     import <package_name>.<sub_package_name>.<module_name>.<...>
#    ```
#
# Let's go ahead and create our own module, with the following three types of elements:
#
# *   A variable `s`
# *   A function `say_hi()`
# *   A class `Greet`

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %% [markdown]
# This command writes (or saves) our module into our working directory so that we can use it again.

# %%
#Import the module we've just made! 
import my_module

# %% [markdown]
# Even though we've imported our module, note that its contents (the variables and functions we've defined within the module) are not directly accessible to us. As such, attempting to access these elements will result in (namespace) errors being thrown. We can safely see such errors using a `try-except` block:

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %% [markdown]
# Learning from this experience, it is important to know that objects in a module are only accessible when prefixed with via dot notation, as illustrated below.

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Example: Importing modules using an alias
# The `import` statement in Python also allows for the use of aliases when referencing a module. Using the `as` keyword, we can save ourselves from having to type otherwise long package names each time we need to access an object from a given module/package. This usually follows the following syntax:
#
# ```python
# import <module_name> as <new_model_name>
# ```
# or
#
# ```python
# from <package_name> import <module_name> as <new_model_name>
# ```
#
# For example:

# %%
# Alias for my_module
import my_module as md

# %% [markdown]
# We can thus treat the alias as the new name for the module.

# %%
# Accessing the variable s using an alias
md.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
# Accessing the empty class, Greet
md.Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Example: Importing modules directly
# Another way to access specific objects in a module is to use the `from` keyword and import them directly:
#
# ```python
# from <module_name> import <x, y, z>
# ```

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# We can see that using the `from xx import yy` structure provides access to the individual elements in the module without having to use dot notation. However, using aliases is the recommended way of importing modules and packages, as this prevents potential confusion when different modules contain functions or classes with the same name.
#
# To select all objects from a module we can use the following command, where the asterisk **( * )** *signifies all* :
#
# ```python
# from <module_name> import*
# ```
# Let's see this in practice one more time:

# %%
from my_module import *

# %% [markdown]
# Now we have access to all our module contents.

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ## Built-in modules
# Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword `import`.
#
# Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the **.py** extension) containing useful utilities are embedded within the standard library.
#
# To **display a list of all available modules**, use the following command:
#
# `help('modules')`

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# c:\Users\OMEN\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# c:\Users\OMEN\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\OMEN\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# 3204bda914b7f2c6f497__mypyc cmd                 matplotlib          sklearn
# IPython             code                matplotlib_inline   sklearn_compat
# OpenSSL             codecs              mccabe              slugify
# PIL                 codeop              mdit_py_plugins     smmap
# PyQt5               collections         mdurl               smtplib
# __future__          colorama            menuinst            sniffio
# __hello__           colorcet            mimetypes           snowballstemmer
# __phello__          colorsys            mistune             socket
# _abc                comm                mkl                 socketserver
# _aix_support        commctrl            mkl_fft             socks
# _android_support    compileall          mkl_random          sockshandler
# _apple_support      concurrent          mmap                sortedcontainers
# _argon2_cffi_bindings conda               mmapfile            soupsieve
# _ast                conda_anaconda_telemetry mmsystem            sphinx
# _asyncio            conda_anaconda_tos  modulefinder        spyder
# _bisect             conda_build         more_itertools      spyder_kernels
# _black_version      conda_content_trust mpmath              sqlalchemy
# _blake2             conda_env           msgpack             sqlite3
# _brotli             conda_index         msvcrt              sre_compile
# _bz2                conda_libmamba_solver multidict           sre_constants
# _cffi_backend       conda_pack          multipledispatch    sre_parse
# _codecs             conda_package_handling multiprocessing     ssl
# _codecs_cn          conda_package_streaming my_module           sspi
# _codecs_hk          conda_token         mypy                sspicon
# _codecs_iso2022     configparser        mypy_extensions     stack_data
# _codecs_jp          constantly          mypyc               start_pythonwin
# _codecs_kr          contextlib          nacl                stat
# _codecs_tw          contextvars         narwhals            statistics
# _collections        contourpy           navigator_updater   statsmodels
# _collections_abc    cookiecutter        nbclient            streamlit
# _colorize           copy                nbconvert           string
# _compat_pickle      copyreg             nbformat            stringprep
# _compression        cpuinfo             nest_asyncio        struct
# _contextvars        cryptography        netbios             subprocess
# _csv                cssselect           netrc               superqt
# _ctypes             csv                 networkx            sympy
# _ctypes_test        ctypes              nltk                symtable
# _datetime           curl                notebook            sys
# _decimal            curses              notebook_shim       sysconfig
# _distutils_hack     cwp                 nt                  tables
# _elementtree        cycler              ntpath              tabnanny
# _functools          cytoolz             ntsecuritycon       tabulate
# _hashlib            dask                nturl2path          tarfile
# _heapq              dask_expr           numba               tblib
# _imp                dataclasses         numbergen           tempfile
# _interpchannels     datashader          numbers             tenacity
# _interpqueues       datetime            numexpr             terminado
# _interpreters       dateutil            numpy               test
# _io                 dbm                 numpydoc            test_pycosat
# _ios_support        dde                 odbc                text_unidecode
# _json               debugpy             opcode              textdistance
# _locale             decimal             openpyxl            textwrap
# _lsprof             decorator           operator            this
# _lzma               defusedxml          optparse            threading
# _markupbase         deprecated          ordered_set         threadpoolctl
# _md5                diff_match_patch    os                  three_merge
# _multibytecodec     difflib             overrides           tifffile
# _multiprocessing    dill                packaging           time
# _nsis               dis                 pandas              timeit
# _opcode             distributed         pandocfilters       timer
# _opcode_metadata    distro              panel               tinycss2
# _operator           docstring_to_markdown param               tkinter
# _osx_support        doctest             parsel              tldextract
# _overlapped         docutils            parso               tlz
# _pickle             dotenv              partd               token
# _plotly_future_     email               pathlib             tokenize
# _plotly_utils       encodings           pathspec            toml
# _py_abc             ensurepip           patsy               tomli
# _pydatetime         enum                pdb                 tomlkit
# _pydecimal          erfa                perfmon             tomllib
# _pyio               errno               pexpect             toolz
# _pylong             et_xmlfile          pickle              tornado
# _pyrepl             evalidate           pickleshare         tqdm
# _pytest             executing           pickletools         trace
# _queue              fastjsonschema      pip                 traceback
# _random             faulthandler        pkce                tracemalloc
# _ruamel_yaml        filecmp             pkg_resources       traitlets
# _sha1               fileinput           pkginfo             truststore
# _sha2               filelock            pkgutil             tty
# _sha3               flake8              platform            turtle
# _signal             flask               platformdirs        turtledemo
# _sitebuiltins       fnmatch             plistlib            twisted
# _socket             fontTools           plotly              typeguard
# _sqlite3            fqdn                pluggy              typer
# _sre                fractions           ply                 types
# _ssl                frozendict          poplib              typing
# _stat               frozenlist          posixpath           typing_extensions
# _statistics         fsspec              poyo                tzdata
# _string             ftplib              pprint              uc_micro
# _strptime           functools           profile             ujson
# _struct             gc                  prometheus_client   unicodedata
# _suggestions        genericpath         prompt_toolkit      unidecode
# _symtable           getopt              propcache           unittest
# _sysconfig          getpass             protego             uri_template
# _system_path        gettext             pstats              urllib
# _testbuffer         git                 psutil              urllib3
# _testcapi           gitdb               pty                 uuid
# _testclinic         github              ptyprocess          venv
# _testclinic_limited glob                pure_eval           w3lib
# _testconsole        gmpy2               py                  warnings
# _testimportmultiple graphlib            py_compile          watchdog
# _testinternalcapi   greenlet            pyarrow             wave
# _testlimitedcapi    gzip                pyasn1              wcwidth
# _testmultiphase     h11                 pyasn1_modules      weakref
# _testsinglephase    h5py                pyclbr              webbrowser
# _thread             hashlib             pycodestyle         webcolors
# _threading_local    heapdict            pycosat             webencodings
# _tkinter            heapq               pycparser           websocket
# _tokenize           hmac                pyct                werkzeug
# _tracemalloc        holoviews           pycurl              whatthepatch
# _typing             html                pydantic            wheel
# _uuid               http                pydantic_core       widgetsnbextension
# _warnings           httpcore            pydantic_settings   win2kras
# _weakref            httpx               pydispatch          win32api
# _weakrefset         hvplot              pydoc               win32clipboard
# _win32sysloader     hyperlink           pydoc_data          win32com
# _win32verstamp_pywin32ctypes idlelib             pydocstyle          win32con
# _winapi             idna                pyexpat             win32console
# _winxptheme         imageio             pyflakes            win32cred
# _wmi                imagesize           pygame              win32crypt
# _yaml               imaplib             pygments            win32cryptcon
# _zoneinfo           imblearn            pylab               win32ctypes
# abc                 importlib           pylint              win32event
# adodbapi            importlib_metadata  pylint_venv         win32evtlog
# afxres              importlib_resources pyls_spyder         win32evtlogutil
# aiobotocore         incremental         pylsp               win32file
# aiohappyeyeballs    inflect             pylsp_black         win32gui
# aiohttp             inflection          pylsp_jsonrpc       win32gui_struct
# aioitertools        iniconfig           pyodbc              win32help
# aiosignal           inspect             pyparsing           win32inet
# alabaster           intake              pytest              win32inetcon
# altair              intervaltree        pythoncom           win32job
# anaconda_anon_usage io                  pythonjsonlogger    win32lz
# anaconda_auth       ipaddress           pytoolconfig        win32net
# anaconda_catalogs   ipykernel           pytz                win32netcon
# anaconda_cli_base   ipykernel_launcher  pyuca               win32pdh
# anaconda_cloud_auth ipywidgets          pyviz_comms         win32pdhquery
# anaconda_navigator  isapi               pywin               win32pdhutil
# anaconda_project    isoduration         pywin32_bootstrap   win32pipe
# annotated_types     isort               pywin32_testutil    win32print
# antigravity         isympy              pywintypes          win32process
# anyio               itemadapter         pywt                win32profile
# appdirs             itemloaders         qdarkstyle          win32ras
# archspec            itertools           qstylizer           win32rcparser
# argon2              itsdangerous        qtawesome           win32security
# argparse            jedi                qtconsole           win32service
# array               jellyfish           qtpy                win32serviceutil
# arrow               jinja2              queue               win32timezone
# ast                 jinja2_time         queuelib            win32trace
# astroid             jmespath            quopri              win32traceutil
# astropy             joblib              random              win32transaction
# astropy_iers_data   json                rasutil             win32ts
# asttokens           json5               re                  win32ui
# async_lru           jsonpatch           readchar            win32uiole
# asyncio             jsonpointer         referencing         win32verstamp
# asyncssh            jsonschema          regcheck            win32wnet
# atexit              jsonschema_specifications regex               win_inet_pton
# atomicwrites        jupyter             regutil             winerror
# attr                jupyter_client      repo_cli            winioctlcon
# attrs               jupyter_console     reprlib             winnt
# autocommand         jupyter_core        requests            winperf
# automat             jupyter_events      requests_file       winpty
# autopep8            jupyter_lsp         requests_toolbelt   winreg
# babel               jupyter_server      rfc3339_validator   winsound
# backports           jupyter_server_terminals rfc3986_validator   winxpgui
# base64              jupyterlab          rich                winxptheme
# bcrypt              jupyterlab_plotly   rlcompleter         wrapt
# bdb                 jupyterlab_pygments roman_numerals      wsgiref
# binaryornot         jupyterlab_server   rope                xarray
# binascii            jupyterlab_widgets  rpds                xlwings
# binstar_client      jwt                 rtree               xlwingsjs
# bisect              keyring             ruamel_yaml         xml
# black               keyword             runpy               xmlrpc
# blackd              kiwisolver          s3fs                xxlimited
# bleach              lazy_loader         sched               xxlimited_35
# blib2to3            lckr_jupyterlab_variableinspector scipy               xxsubtype
# blinker             libarchive          scrapy              xyzservices
# bokeh               libmambapy          seaborn             yaml
# boltons             lief                secrets             yapf
# botocore            linecache           select              yapf_third_party
# bottleneck          linkify_it          selectors           yapftests
# brotli              llvmlite            semver              yarl
# bs4                 lmdb                send2trash          zict
# builtins            locale              service_identity    zipapp
# bz2                 locket              servicemanager      zipfile
# cProfile            logging             setuptools          zipimport
# cachetools          lxml                shellingham         zipp
# calendar            lz4                 shelve              zlib
# certifi             lzma                shlex               zmq
# cffi                mailbox             shutil              zoneinfo
# chardet             markdown            signal              zope
# charset_normalizer  markdown_it         sipbuild            zstandard
# click               markupsafe          site
# cloudpickle         marshal             six
# cmath               math                skimage
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# Alternatively, the `dir()` function is a built-in function that can be used to **list all the function names (or variable names) in a module**:
#
# `dir(module_name)`

# %%
# Import math module 
import math 

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))

# %% [markdown]
# ## Summary
#
# In this train, we learned how to create, import, and use modules. We also explored the use of built-in modules in Python and how to determine what functions are present within modules.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:140px";/>
# </div>
